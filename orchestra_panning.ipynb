# %%
import numpy as np
import msignal
from scipy import signal
import matplotlib.pyplot as plt
import soundfile as sf
import struct

# %%
#ホールのインパルス応答
data = []
with open('/Users/shugoto/Desktop/programming/Mypythonproject/orchestra_panning/sc10s.DAT', 'rb') as f:
    while True:
        bytes = f.read(2)
        if bytes:
            data.append(struct.unpack('<h', bytes)[0])
        else:
            break
            
def calc_wav(n):
    return n /32768
            
data_ir = list(map(calc_wav, data))
plt.plot(data_ir)

# %%
#それぞれの角度の左耳へのインパルス応答
data = []
with open('/Users/shugoto/Desktop/programming/Mypythonproject/orchestra_panning/L0e005a.DAT', 'rb') as f:
    while True:
        bytes = f.read(2)
        if bytes:
            data.append(struct.unpack('<h', bytes)[0])
        else:
            break
            
def calc_wav(n):
    return n /32768
            
data_005 = list(map(calc_wav, data))
plt.plot(data_005)

# %%
data = []
with open('/Users/shugoto/Desktop/programming/Mypythonproject/orchestra_panning/L0e045a.DAT', 'rb') as f:
    while True:
        bytes = f.read(2)
        if bytes:
            data.append(struct.unpack('<h', bytes)[0])
        else:
            break
            
def calc_wav(n):
    return n /32768
            
data_045 = list(map(calc_wav, data))
plt.plot(data_045)

# %%
data = []
with open('/Users/shugoto/Desktop/programming/Mypythonproject/orchestra_panning/L0e060a.DAT', 'rb') as f:
    while True:
        bytes = f.read(2)
        if bytes:
            data.append(struct.unpack('<h', bytes)[0])
        else:
            break
            
def calc_wav(n):
    return n /32768
            
data_060 = list(map(calc_wav, data))
plt.plot(data_060)

# %%
data = []
with open('/Users/shugoto/Desktop/programming/Mypythonproject/orchestra_panning/L0e300a.DAT', 'rb') as f:
    while True:
        bytes = f.read(2)
        if bytes:
            data.append(struct.unpack('<h', bytes)[0])
        else:
            break
            
def calc_wav(n):
    return n /32768
            
data_300 = list(map(calc_wav, data))
plt.plot(data_300)

# %%
data = []
with open('/Users/shugoto/Desktop/programming/Mypythonproject/orchestra_panning/L0e315a.DAT', 'rb') as f:
    while True:
        bytes = f.read(2)
        if bytes:
            data.append(struct.unpack('<h', bytes)[0])
        else:
            break
            
def calc_wav(n):
    return n /32768
            
data_315 = list(map(calc_wav, data))
plt.plot(data_315)

# %%
data = []
with open('/Users/shugoto/Desktop/programming/Mypythonproject/orchestra_panning/L0e355a.DAT', 'rb') as f:
    while True:
        bytes = f.read(2)
        if bytes:
            data.append(struct.unpack('<h', bytes)[0])
        else:
            break
            
def calc_wav(n):
    return n /32768
            
data_355 = list(map(calc_wav, data))
plt.plot(data_355)

# %%
#左耳へのvn1a_lの信号処理
#完成した音源はp_vn1a_lへ
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/vn1a_l.wav"
data_vn1a_l, fs_sig = sf.read(wav_file)
data_vn1a_l = data_vn1a_l[:, 0]

#畳み込み演算
p_vn1a_l = signal.fftconvolve(data_vn1a_l, data_300)
p_vn1a_l = signal.fftconvolve(p_vn1a_l, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_vn1a_l.wav', p_vn1a_l, fs_sig)



#右耳へのvn1a_rの信号処理
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/vn1a_r.wav"
data_vn1a_r, fs_sig = sf.read(wav_file)
data_vn1a_r = data_vn1a_r[:, 0]

#畳み込み演算
p_vn1a_r = signal.fftconvolve(data_vn1a_r, data_060)
p_vn1a_r = signal.fftconvolve(p_vn1a_r, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_vn1a_r.wav', p_vn1a_r, fs_sig)

# %%
#左耳へのvn1b_lの信号処理
#完成した音源はp_vn1b_lへ
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/vn1b_l.wav"
data_vn1b_l, fs_sig = sf.read(wav_file)
data_vn1b_l = data_vn1b_l[:, 0]

#畳み込み演算
p_vn1b_l = signal.fftconvolve(data_vn1b_l, data_300)
p_vn1b_l = signal.fftconvolve(p_vn1b_l, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_vn1b_l.wav', p_vn1b_l, fs_sig)



#右耳へのvn1b_rの信号処理
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/vn1b_r.wav"
data_vn1b_r, fs_sig = sf.read(wav_file)
data_vn1b_r = data_vn1b_r[:, 0]

#畳み込み演算
p_vn1b_r = signal.fftconvolve(data_vn1b_r, data_060)
p_vn1b_r = signal.fftconvolve(p_vn1b_r, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_vn1b_r.wav', p_vn1b_r, fs_sig)

# %%
#左耳へのvn2a_lの信号処理
#完成した音源はp_vn2a_lへ
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/vn2a_l.wav"
data_vn2a_l, fs_sig = sf.read(wav_file)
data_vn2a_l = data_vn2a_l[:, 0]

#畳み込み演算
p_vn2a_l = signal.fftconvolve(data_vn2a_l, data_060)
p_vn2a_l = signal.fftconvolve(p_vn2a_l, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_vn2a_l.wav', p_vn2a_l, fs_sig)



#右耳へのvn2a_rの信号処理
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/vn2a_r.wav"
data_vn2a_r, fs_sig = sf.read(wav_file)
data_vn2a_r = data_vn2a_r[:, 0]

#畳み込み演算
p_vn2a_r = signal.fftconvolve(data_vn2a_r, data_300)
p_vn2a_r = signal.fftconvolve(p_vn2a_r, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_vn2a_r.wav', p_vn2a_r, fs_sig)

# %%
#左耳へのvn2b_lの信号処理
#完成した音源はp_vn2b_lへ
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/vn2b_l.wav"
data_vn2b_l, fs_sig = sf.read(wav_file)
data_vn2b_l = data_vn2b_l[:, 0]

#畳み込み演算
p_vn2b_l = signal.fftconvolve(data_vn2b_l, data_060)
p_vn2b_l = signal.fftconvolve(p_vn2b_l, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_vn2b_l.wav', p_vn2b_l, fs_sig)



#右耳へのvn2b_rの信号処理
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/vn2b_r.wav"
data_vn2b_r, fs_sig = sf.read(wav_file)
data_vn2b_r = data_vn2b_r[:, 0]

#畳み込み演算
p_vn2b_r = signal.fftconvolve(data_vn2b_r, data_300)
p_vn2b_r = signal.fftconvolve(p_vn2b_r, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_vn2b_r.wav', p_vn2b_r, fs_sig)

# %%
#左耳へのvlaa_lの信号処理
#完成した音源はp_vlaa_lへ
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/vlaa_l.wav"
data_vlaa_l, fs_sig = sf.read(wav_file)
data_vlaa_l = data_vlaa_l[:, 0]

#畳み込み演算
p_vlaa_l = signal.fftconvolve(data_vlaa_l, data_045)
p_vlaa_l = signal.fftconvolve(p_vlaa_l, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_vlaa_l.wav', p_vlaa_l, fs_sig)



#右耳へのvlaa_rの信号処理
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/vlaa_r.wav"
data_vlaa_r, fs_sig = sf.read(wav_file)
data_vlaa_r = data_vlaa_r[:, 0]

#畳み込み演算
p_vlaa_r = signal.fftconvolve(data_vlaa_r, data_315)
p_vlaa_r = signal.fftconvolve(p_vlaa_r, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_vlaa_r.wav', p_vlaa_r, fs_sig)

# %%
#左耳へのvlab_lの信号処理
#完成した音源はp_vlab_lへ
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/vlab_l.wav"
data_vlab_l, fs_sig = sf.read(wav_file)
data_vlab_l = data_vlab_l[:, 0]

#畳み込み演算
p_vlab_l = signal.fftconvolve(data_vlab_l, data_045)
p_vlab_l = signal.fftconvolve(p_vlab_l, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_vlab_l.wav', p_vlab_l, fs_sig)



#右耳へのvlaa_rの信号処理
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/vlab_r.wav"
data_vlab_r, fs_sig = sf.read(wav_file)
data_vlab_r = data_vlab_r[:, 0]

#畳み込み演算
p_vlab_r = signal.fftconvolve(data_vlab_r, data_315)
p_vlab_r = signal.fftconvolve(p_vlab_r, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_vlab_r.wav', p_vlab_r, fs_sig)

# %%
#左耳へのvc_lの信号処理
#完成した音源はp_vc_lへ
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/vc_l.wav"
data_vc_l, fs_sig = sf.read(wav_file)
data_vc_l = data_vc_l[:, 0]

#畳み込み演算
p_vc_l = signal.fftconvolve(data_vc_l, data_315)
p_vc_l = signal.fftconvolve(p_vc_l, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_vc_l.wav', p_vc_l, fs_sig)



#右耳へのvc_rの信号処理
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/vc_r.wav"
data_vc_r, fs_sig = sf.read(wav_file)
data_vc_r = data_vc_r[:, 0]

#畳み込み演算
p_vc_r = signal.fftconvolve(data_vc_r, data_045)
p_vc_r = signal.fftconvolve(p_vc_r, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_vc_r.wav', p_vc_r, fs_sig)

# %%
#左耳へのcb_lの信号処理
#完成した音源はp_cb_lへ
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/cb_l.wav"
data_cb_l, fs_sig = sf.read(wav_file)
data_cb_l = data_cb_l[:, 0]

#畳み込み演算
p_cb_l = signal.fftconvolve(data_cb_l, data_300)
p_cb_l = signal.fftconvolve(p_cb_l, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_cb_l.wav', p_cb_l, fs_sig)



#右耳へのcb_rの信号処理
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/cb_r.wav"
data_cb_r, fs_sig = sf.read(wav_file)
data_cb_r = data_cb_r[:, 0]

#畳み込み演算
p_cb_r = signal.fftconvolve(data_cb_r, data_060)
p_cb_r = signal.fftconvolve(p_cb_r, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_cb_r.wav', p_cb_r, fs_sig)

# %%
#左耳へのhr1_lの信号処理
#完成した音源はp_hr1_lへ
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/hr1_l.wav"
data_hr1_l, fs_sig = sf.read(wav_file)
data_hr1_l = data_hr1_l[:, 0]

#畳み込み演算
p_hr1_l = signal.fftconvolve(data_hr1_l, data_315)
p_hr1_l = signal.fftconvolve(p_hr1_l, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_hr1_l.wav', p_hr1_l, fs_sig)



#右耳へのcb_rの信号処理
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/hr1_r.wav"
data_hr1_r, fs_sig = sf.read(wav_file)
data_hr1_r = data_hr1_r[:, 0]

#畳み込み演算
p_hr1_r = signal.fftconvolve(data_hr1_r, data_045)
p_hr1_r = signal.fftconvolve(p_hr1_r, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_hr1_r.wav', p_hr1_r, fs_sig)

# %%
#左耳へのhr2_lの信号処理
#完成した音源はp_hr2_lへ
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/hr2_l.wav"
data_hr2_l, fs_sig = sf.read(wav_file)
data_hr2_l = data_hr2_l[:, 0]

#畳み込み演算
p_hr2_l = signal.fftconvolve(data_hr2_l, data_315)
p_hr2_l = signal.fftconvolve(p_hr2_l, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_hr2_l.wav', p_hr2_l, fs_sig)



#右耳へのcb_rの信号処理
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/hr2_r.wav"
data_hr2_r, fs_sig = sf.read(wav_file)
data_hr2_r = data_hr2_r[:, 0]

#畳み込み演算
p_hr2_r = signal.fftconvolve(data_hr2_r, data_045)
p_hr2_r = signal.fftconvolve(p_hr2_r, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_hr2_r.wav', p_hr2_r, fs_sig)

# %%
#左耳へのcl1_lの信号処理
#完成した音源はp_cl1_lへ
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/cl1_l.wav"
data_cl1_l, fs_sig = sf.read(wav_file)
data_cl1_l = data_cl1_l[:, 0]

#畳み込み演算
p_cl1_l = signal.fftconvolve(data_cl1_l, data_355)
p_cl1_l = signal.fftconvolve(p_cl1_l, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_cl1_l.wav', p_cl1_l, fs_sig)



#右耳へのcb_rの信号処理
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/cl1_r.wav"
data_cl1_r, fs_sig = sf.read(wav_file)
data_cl1_r = data_cl1_r[:, 0]

#畳み込み演算
p_cl1_r = signal.fftconvolve(data_cl1_r, data_005)
p_cl1_r = signal.fftconvolve(p_cl1_r, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_cl1_r.wav', p_cl1_r, fs_sig)

# %%
#左耳へのcl2_lの信号処理
#完成した音源はp_cl2_lへ
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/cl2_l.wav"
data_cl2_l, fs_sig = sf.read(wav_file)
data_cl2_l = data_cl2_l[:, 0]

#畳み込み演算
p_cl2_l = signal.fftconvolve(data_cl2_l, data_355)
p_cl2_l = signal.fftconvolve(p_cl2_l, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_cl2_l.wav', p_cl2_l, fs_sig)



#右耳へのcb_rの信号処理
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/cl2_r.wav"
data_cl2_r, fs_sig = sf.read(wav_file)
data_cl2_r = data_cl2_r[:, 0]

#畳み込み演算
p_cl2_r = signal.fftconvolve(data_cl2_r, data_005)
p_cl2_r = signal.fftconvolve(p_cl2_r, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_cl2_r.wav', p_cl2_r, fs_sig)

# %%
#左耳へのfl1_lの信号処理
#完成した音源はp_fl1_lへ
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/fl1_l.wav"
data_fl1_l, fs_sig = sf.read(wav_file)
data_fl1_l = data_fl1_l[:, 0]

#畳み込み演算
p_fl1_l = signal.fftconvolve(data_fl1_l, data_355)
p_fl1_l = signal.fftconvolve(p_fl1_l, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_fl1_l.wav', p_fl1_l, fs_sig)



#右耳へのcb_rの信号処理
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/fl1_r.wav"
data_fl1_r, fs_sig = sf.read(wav_file)
data_fl1_r = data_fl1_r[:, 0]

#畳み込み演算
p_fl1_r = signal.fftconvolve(data_fl1_r, data_005)
p_fl1_r = signal.fftconvolve(p_fl1_r, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_fl1_r.wav', p_fl1_r, fs_sig)

# %%
#左耳へのfl2_lの信号処理
#完成した音源はp_fl2_lへ
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/fl2_l.wav"
data_fl2_l, fs_sig = sf.read(wav_file)
data_fl2_l = data_fl2_l[:, 0]

#畳み込み演算
p_fl2_l = signal.fftconvolve(data_fl2_l, data_355)
p_fl2_l = signal.fftconvolve(p_fl2_l, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_fl2_l.wav', p_fl2_l, fs_sig)



#右耳へのcb_rの信号処理
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/fl2_r.wav"
data_fl2_r, fs_sig = sf.read(wav_file)
data_fl2_r = data_fl2_r[:, 0]

#畳み込み演算
p_fl2_r = signal.fftconvolve(data_fl2_r, data_005)
p_fl2_r = signal.fftconvolve(p_fl2_r, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_fl2_r.wav', p_fl2_r, fs_sig)

# %%
#左耳へのob1_lの信号処理
#完成した音源はp_ob1_lへ
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/ob1_l.wav"
data_ob1_l, fs_sig = sf.read(wav_file)
data_ob1_l = data_ob1_l[:, 0]

#畳み込み演算
p_ob1_l = signal.fftconvolve(data_ob1_l, data_005)
p_ob1_l = signal.fftconvolve(p_ob1_l, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_ob1_l.wav', p_ob1_l, fs_sig)



#右耳へのcb_rの信号処理
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/ob1_r.wav"
data_ob1_r, fs_sig = sf.read(wav_file)
data_ob1_r = data_ob1_r[:, 0]

#畳み込み演算
p_ob1_r = signal.fftconvolve(data_ob1_r, data_355)
p_ob1_r = signal.fftconvolve(p_ob1_r, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_ob1_r.wav', p_ob1_r, fs_sig)

# %%
#左耳へのob2_lの信号処理
#完成した音源はp_ob2_lへ
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/ob2_l.wav"
data_ob2_l, fs_sig = sf.read(wav_file)
data_ob2_l = data_ob2_l[:, 0]

#畳み込み演算
p_ob2_l = signal.fftconvolve(data_ob2_l, data_005)
p_ob2_l = signal.fftconvolve(p_ob2_l, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_ob2_l.wav', p_ob2_l, fs_sig)



#右耳へのcb_rの信号処理
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/ob2_r.wav"
data_ob2_r, fs_sig = sf.read(wav_file)
data_ob2_r = data_ob2_r[:, 0]

#畳み込み演算
p_ob2_r = signal.fftconvolve(data_ob2_r, data_355)
p_ob2_r = signal.fftconvolve(p_ob2_r, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_ob2_r.wav', p_ob2_r, fs_sig)

# %%
#左耳へのfg1_lの信号処理
#完成した音源はp_fg1_lへ
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/fg1_l.wav"
data_fg1_l, fs_sig = sf.read(wav_file)
data_fg1_l = data_fg1_l[:, 0]

#畳み込み演算
p_fg1_l = signal.fftconvolve(data_fg1_l, data_005)
p_fg1_l = signal.fftconvolve(p_fg1_l, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_fg1_l.wav', p_fg1_l, fs_sig)



#右耳へのcb_rの信号処理
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/fg1_r.wav"
data_fg1_r, fs_sig = sf.read(wav_file)
data_fg1_r = data_fg1_r[:, 0]

#畳み込み演算
p_fg1_r = signal.fftconvolve(data_fg1_r, data_355)
p_fg1_r = signal.fftconvolve(p_fg1_r, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_fg1_r.wav', p_fg1_r, fs_sig)

# %%
#左耳へのfg2_lの信号処理
#完成した音源はp_fg2_lへ
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/fg2_l.wav"
data_fg2_l, fs_sig = sf.read(wav_file)
data_fg2_l = data_fg2_l[:, 0]

#畳み込み演算
p_fg2_l = signal.fftconvolve(data_fg2_l, data_005)
p_fg2_l = signal.fftconvolve(p_fg2_l, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_fg2_l.wav', p_fg2_l, fs_sig)



#右耳へのcb_rの信号処理
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/fg2_r.wav"
data_fg2_r, fs_sig = sf.read(wav_file)
data_fg2_r = data_fg2_r[:, 0]

#畳み込み演算
p_fg2_r = signal.fftconvolve(data_fg2_r, data_355)
p_fg2_r = signal.fftconvolve(p_fg2_r, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_fg2_r.wav', p_fg2_r, fs_sig)

# %%
#左耳へのtp1_lの信号処理
#完成した音源はp_tp1_lへ
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/tr1_l.wav"
data_tr1_l, fs_sig = sf.read(wav_file)
data_tr1_l = data_tr1_l[:, 0]

#畳み込み演算
p_tr1_l = signal.fftconvolve(data_tr1_l, data_005)
p_tr1_l = signal.fftconvolve(p_tr1_l, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_tr1_l.wav', p_tr1_l, fs_sig)



#右耳へのcb_rの信号処理
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/tr1_r.wav"
data_tr1_r, fs_sig = sf.read(wav_file)
data_tr1_r = data_tr1_r[:, 0]

#畳み込み演算
p_tr1_r = signal.fftconvolve(data_tr1_r, data_355)
p_tr1_r = signal.fftconvolve(p_tr1_r, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_tr1_r.wav', p_tr1_r, fs_sig)

# %%
#左耳へのtp2_lの信号処理
#完成した音源はp_tp2_lへ
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/tr2_l.wav"
data_tr2_l, fs_sig = sf.read(wav_file)
data_tr2_l = data_tr2_l[:, 0]

#畳み込み演算
p_tr2_l = signal.fftconvolve(data_tr2_l, data_005)
p_tr2_l = signal.fftconvolve(p_tr2_l, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_tr2_l.wav', p_tr2_l, fs_sig)



#右耳へのcb_rの信号処理
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/tr2_r.wav"
data_tr2_r, fs_sig = sf.read(wav_file)
data_tr2_r = data_tr2_r[:, 0]

#畳み込み演算
p_tr2_r = signal.fftconvolve(data_tr2_r, data_355)
p_tr2_r = signal.fftconvolve(p_tr2_r, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_tr2_r.wav', p_tr2_r, fs_sig)

# %%
#左耳へのtp2_lの信号処理
#完成した音源はp_tp2_lへ
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/timp.wav"
data_timp, fs_sig = sf.read(wav_file)
data_timp = data_timp[:, 0]

#畳み込み演算

p_timp = signal.fftconvolve(data_timp, data_ir)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/p_timp.wav', p_timp, fs_sig)

# %%
wav_file = "/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/beethoven_strings.wav"
data_all, fs_sig = sf.read(wav_file)
lowpath = signal.firwin(numtaps=255, cutoff=2000, fs=fs_sig)
lowcutwav = signal.lfilter(lowpath, 1, data_all)
sf.write('/Users/shugoto/Desktop/programming/MyPythonProject/orchestra_panning/clean_beethoven_strings.wav', lowcutwav, fs_sig)
